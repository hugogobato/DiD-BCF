# %% [markdown]
# # DiD-BCF — B1_selection_obs (linearity_degree=3)
#
# **Workstream B1 · canonical DiD (selection on unobservables)**
#
# continuity check: selection on observables only
#
# Fits DiD-BCF on the `B1_selection_obs` scenario at `linearity_degree=3` and reports
# metrics for **both** the plain DiD-BCF posterior and the proposed **posterior
# correction** (Algorithm 1 of the theory note), so the correction can be judged
# directly. Panel: N=200, 4 pre + 4 post periods.
#
# > **Colab:** upload just this notebook and *Run all* — the first cell installs the
# > dependencies and the second clones the engine automatically.

# %%
# Colab: install the DiD-BCF dependencies (stochtree provides the BCF sampler).
# %pip install -q stochtree scikit-learn joblib tqdm pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.3 MB/s eta 0:00:00

# %%
import os, sys

# --- Locate the DiD-BCF engine ------------------------------------------------
# So you can upload just THIS notebook to Colab and Run all. Resolution order:
#   1. `did_bcf_revision` already importable;
#   2. running inside a repo checkout (the parent folder holds the package);
#   3. otherwise clone https://github.com/hugogobato/DiD-BCF and use it.
REPO_URL = "https://github.com/hugogobato/DiD-BCF.git"
ENGINE_SUBDIR = os.path.join("DiD-BCF", "Simulation_Studies_Revision")

def _locate_root():
    try:
        import did_bcf_revision  # noqa: F401
        return os.path.dirname(os.path.dirname(did_bcf_revision.__file__))
    except Exception:
        pass
    parent = os.path.abspath(os.path.join(os.getcwd(), ".."))
    if os.path.isdir(os.path.join(parent, "did_bcf_revision")):
        return parent
    if not os.path.isdir("DiD-BCF"):
        import subprocess
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL], check=True)
    return os.path.abspath(ENGINE_SUBDIR)

ROOT = _locate_root()
sys.path.insert(0, ROOT)
print("Using DiD-BCF engine at:", ROOT)

from did_bcf_revision.runner import run_named
from did_bcf_revision.metrics import (compute_metrics, plain_vs_corrected,
                                      surface_metrics)
# Out:
# Using DiD-BCF engine at: /content/DiD-BCF/Simulation_Studies_Revision

# %%
REPS = 100      # replications (lower for a quick smoke test)
JOBS = 1        # parallel reps (keep 1 on a single-core/GPU Colab)

bcf_params = dict(num_gfr=50, num_mcmc=500, keep_every=5, num_chains=3)

summaries = run_named(
    "B1_selection_obs",
    linearity_degree=3,
    reps=REPS,
    jobs=JOBS,
    bcf_params=bcf_params,
    prop_method="logit",   # pilot propensity for the posterior correction
    n_splits=2,            # cross-fitting folds for the correction
)
summaries.head()
# Out:
# [B1_selection_obs_lin_3] canonical DGP | N=(200,) | reps=100 | 100 fits | jobs=1
# B1_selection_obs: 100%|██████████| 100/100 [6:01:24<00:00, 216.85s/fit]
# [B1_selection_obs_lin_3] wrote 2000 rows -> /content/DiD-BCF/Simulation_Studies_Revision/Results/summaries_B1_selection_obs_lin_3.csv
#          dgp           setting  linearity_degree    N  rep estimand_type  \
# 0  canonical  B1_selection_obs                 3  200    0          GATT
# 1  canonical  B1_selection_obs                 3  200    0          GATT
# 2  canonical  B1_selection_obs                 3  200    0          GATT
# 3  canonical  B1_selection_obs                 3  200    0          GATT
# 4  canonical  B1_selection_obs                 3  200    0            ES
#
#   estimand_id    g    t    k  ...   p_bayes  surf_rmse  surf_mae  surf_n  \
# 0     g=4_t=4  4.0  4.0  0.0  ...  0.280667        NaN       NaN     NaN
# 1     g=4_t=5  4.0  5.0  1.0  ...  0.381333        NaN       NaN     NaN
# 2     g=4_t=6  4.0  6.0  2.0  ...  0.319333        NaN       NaN     NaN
# 3     g=4_t=7  4.0  7.0  3.0  ...  0.387333        NaN       NaN     NaN
# 4         k=0  NaN  NaN  0.0  ...  0.280667        NaN       NaN     NaN
#
#    surf_mape  surf_cover95  surf_len95  surf_cover90  surf_len90      true
# 0        NaN           NaN         NaN           NaN         NaN  3.924677
# 1        NaN           NaN         NaN           NaN         NaN  3.924677
# 2        NaN           NaN         NaN           NaN         NaN  3.924677
# 3        NaN           NaN         NaN           NaN         NaN  3.924677
# 4        NaN           NaN         NaN           NaN         NaN  3.924677
#
# [5 rows x 27 columns]

# %%
# Decomposed metrics: bias, MC SD/variance, RMSE, MAE, MAPE, coverage 90/95,
# interval length, calibration ratio (avg_post_sd/emp_sd), size/power and their
# Monte-Carlo SEs -- for plain AND corrected DiD-BCF.
metrics = compute_metrics(summaries)
plain_vs_corrected(metrics)
# Out:
#          dgp           setting  linearity_degree    N estimand_type  \
# 0  canonical  B1_selection_obs                 3  200           ATT
# 1  canonical  B1_selection_obs                 3  200            ES
# 2  canonical  B1_selection_obs                 3  200            ES
# 3  canonical  B1_selection_obs                 3  200            ES
# 4  canonical  B1_selection_obs                 3  200            ES
# 5  canonical  B1_selection_obs                 3  200          GATT
# 6  canonical  B1_selection_obs                 3  200          GATT
# 7  canonical  B1_selection_obs                 3  200          GATT
# 8  canonical  B1_selection_obs                 3  200          GATT
#
#   estimand_id   role  bias_corrected  bias_plain  cover90_corrected  ...  \
# 0         ATT  power       -0.650575   -3.897885               0.31  ...
# 1         k=0  power       -0.681530   -3.933104               0.31  ...
# 2         k=1  power       -0.639359   -3.917351               0.33  ...
# 3         k=2  power       -0.668241   -3.893708               0.35  ...
# 4         k=3  power       -0.613169   -3.847378               0.36  ...
# 5     g=4_t=4  power       -0.681530   -3.933104               0.31  ...
# 6     g=4_t=5  power       -0.639359   -3.917351               0.33  ...
# 7     g=4_t=6  power       -0.668241   -3.893708               0.35  ...
# 8     g=4_t=7  power       -0.613169   -3.847378               0.36  ...
#
#    len95_corrected  len95_plain  mae_corrected  mae_plain  reject05_corrected  \
# 0         0.970990     2.203033       0.988958   3.897885                1.00
# 1         1.218489     2.033658       1.005332   3.933104                0.99
# 2         1.192155     2.248884       0.971966   3.917351                1.00
# 3         1.202882     2.435268       1.032747   3.893708                1.00
# 4         1.259300     2.614892       1.013795   3.847378                1.00
# 5         1.218489     2.033658       1.005332   3.933104                0.99
# 6         1.192155     2.248884       0.971966   3.917351                1.00
# 7         1.202882     2.435268       1.032747   3.893708                1.00
# 8         1.259300     2.614892       1.013795   3.847378                1.00
#
#    reject05_plain  rmse_corrected  rmse_plain  sd_ratio_corrected  \
# 0             0.0        1.258620    3.899969            0.224327
# 1             0.0        1.275016    3.934231            0.280748
# 2             0.0        1.229530    3.919853            0.283740
# 3             0.0        1.284896    3.896763            0.271635
# 4             0.0        1.294704    3.851026            0.276737
# 5             0.0        1.275016    3.934231            0.280748
# 6             0.0        1.229530    3.919853            0.283740
# 7             0.0        1.284896    3.896763            0.271635
# 8             0.0        1.294704    3.851026            0.276737
#
#    sd_ratio_plain
# 0        5.888331
# 1       26.644354
# 2        5.205386
# 3        4.568054
# 4        4.534429
# 5       26.644354
# 6        5.205386
# 7        4.568054
# 8        4.534429
#
# [9 rows x 25 columns]

# %% [markdown]
# ## CATT-surface metrics (the paper's headline RMSE/MAE/MAPE)
#
# Within-replication RMSE/MAE/MAPE over the *individual* treated observations
# (mean +/- SD across runs) plus the *pointwise* CATT coverage -- the evidence
# that DiD-BCF recovers the heterogeneous effect that GATT-only methods cannot.

# %%
surface_metrics(summaries)
# Out:
#          dgp           setting  linearity_degree    N     method  n_reps  \
# 0  canonical  B1_selection_obs                 3  200  corrected     100
# 1  canonical  B1_selection_obs                 3  200      plain     100
#
#    avg_n_treated_obs  surf_rmse_mean  surf_rmse_sd  surf_mae_mean  ...  \
# 0             404.32        1.414032      0.590240       1.234360  ...
# 1             404.32        3.990856      0.123123       3.897885  ...
#
#    surf_mape_mean  surf_mape_sd  surf_cover90_mean  surf_cover90_sd  \
# 0        0.316158      0.142368           0.243307         0.141962
# 1        0.990783      0.023480           0.000000         0.000000
#
#    surf_cover95_mean  surf_cover95_sd  surf_len90_mean  surf_len90_sd  \
# 0           0.291237         0.163115         0.996814       0.333332
# 1           0.000000         0.000000         1.849177       0.076922
#
#    surf_len95_mean  surf_len95_sd
# 0         1.218207       0.432201
# 1         2.340383       0.104556
#
# [2 rows x 21 columns]
