# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import random
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tqdm import tqdm  # Import tqdm for the progress bar

# %%
def generate_did_data(
    n_units=200,
    num_pre_periods=5,
    num_post_periods=5,
    linearity_degree=1, # 1: fully linear, 2: half X non-linear, 3: treatment + all X non-linear
    propensity_coeffs={'intercept': 0.0, 'X1': 0.5, 'X7': -0.5}, # Coefficients for propensity score (using static X1 and X7)
    pre_trend_bias_delta=0.2,
    epsilon_scale=1,
    seed=42
):
    """
    Generates panel data for Difference-in-Differences analysis with controllable pre-trends,
    non-linearity, conditional treatment effects, and propensity score based treatment assignment.

    Generates exactly 8 covariates:
    - X1: Bernoulli(p=0.66) - Static (unit-level)
    - X2: Bernoulli(p=0.45) - Time-varying
    - X3: Normal(0,1) - Time-varying (Used in CATE)
    - X4: Normal(0,1) - Time-varying
    - X5: Normal(0,1) - Time-varying
    - X6: Normal(0,1) - Time-varying
    - X7: Normal(0,1) - Static (unit-level, Used in Propensity Score)
    - X8: Categorical{1,2,3,4} probs {0.3, 0.1, 0.2, 0.4} - Time-varying (Used in CATE)

    Args:
        n_units (int): Number of units (e.g., individuals, firms).
        num_pre_periods (int): Number of periods before treatment.
        num_post_periods (int): Number of periods after treatment.
        linearity_degree (int): Degree of linearity in the DGP:
            1: Fully linear Y, conditional treatment effect based on X3/X8.
            2: X1,X2,X3,X4 non-linear, conditional treatment effect based on X3/X8.
            3: All X covariates non-linear, conditional treatment effect based on X3/X8.
        propensity_coeffs (dict): Dictionary with coefficients for the propensity score calculation.
                                  Expected keys: 'intercept', 'X1', 'X7'.
                                  p = sigmoid(intercept + X1*coeff_X1 + X7*coeff_X7)
        pre_trend_bias_delta (float): Bias parameter to induce pre-trends in the treated group.
        epsilon_scale (float): Scale (standard deviation) of the error term.
        seed (int): Random seed for reproducibility.

    Returns:
        pd.DataFrame: Generated panel data in long format with 'Y', covariates (X1-X8), 'treated_group',
                      'post_treatment', 'CATE', and 'propensity_score'.
    """
    np.random.seed(seed)
    total_periods = num_pre_periods + num_post_periods
    total_observations = n_units * total_periods
    unit_ids = np.arange(n_units)
    time_periods = np.arange(total_periods)

    # --- Fixed Covariate Betas ---
    beta_x = np.array([-0.75, 0.5, -0.5, -1.30, 1.8, 2.5, -1.0, 0.3])
    if len(beta_x) != 8:
        raise ValueError("beta_x must have exactly 8 elements.")

    # --- Set base treatment_effect_beta based on linearity_degree ---
    if linearity_degree == 1 or linearity_degree == 2:
        treatment_effect_beta = 0
    elif linearity_degree == 3:
        treatment_effect_beta = 0
    else:
        raise ValueError(f"linearity_degree ({linearity_degree}) must be 1, 2, or 3.")

    # --- Generate Static Covariates (Unit-Level) ---
    X1_unit = np.random.binomial(n=1, p=0.66, size=n_units) # Static Bernoulli for Propensity
    X7_unit = np.random.normal(0, 1, size=n_units)          # Static Numerical for Propensity

    # --- Propensity Score Calculation and Treatment Assignment ---
    z_unit = (propensity_coeffs['intercept'] +
              propensity_coeffs['X1'] * X1_unit +
              propensity_coeffs['X7'] * X7_unit)
    propensity_scores_unit = 1 / (1 + np.exp(-z_unit))
    treatment_assignment_random = np.random.uniform(0, 1, size=n_units)
    treated_units_mask = treatment_assignment_random < propensity_scores_unit
    treated_units = unit_ids[treated_units_mask]

    # --- Create Base DataFrame and Map Static Data ---
    data = pd.DataFrame({
        'unit_id': np.repeat(unit_ids, total_periods),
        'time': np.tile(time_periods, n_units)
    })
    unit_map = data['unit_id'].values # Index mapper from panel row to unit

    data['X1'] = X1_unit[unit_map]
    data['X7'] = X7_unit[unit_map]
    data['propensity_score'] = propensity_scores_unit[unit_map]
    data['treated_group'] = np.isin(data['unit_id'], treated_units).astype(int)

    # --- Generate Time-Varying Covariates (Panel-Level) ---
    data['X2'] = np.random.binomial(n=1, p=0.45, size=total_observations) # Time-varying Bernoulli
    data['X3'] = np.random.normal(0, 1, size=total_observations)         # Time-varying Numerical (for CATE)
    data['X4'] = np.random.normal(0, 1, size=total_observations)         # Time-varying Numerical
    data['X5'] = np.random.normal(0, 1, size=total_observations)         # Time-varying Numerical
    data['X6'] = np.random.normal(0, 1, size=total_observations)         # Time-varying Numerical

    # Time-varying Categorical (for CATE)
    cat_categories = [1, 2, 3, 4]
    cat_probabilities = [0.3, 0.1, 0.2, 0.4]
    data['X8'] = np.random.choice(cat_categories, size=total_observations, p=cat_probabilities)

    # --- Time indicators ---
    treatment_period = num_pre_periods
    data['post_treatment'] = np.where(data['time'] >= treatment_period, 1, 0)
    data['time_trend'] = data['time']

    # --- Generate error term ---
    data['epsilon'] = np.random.normal(scale=epsilon_scale, size=total_observations)

    # --- DGP parameters ---
    beta_0 = -0.5 # Intercept
    beta_treated = 0.75 # Main effect of treated group (alpha_i)
    beta_time = 0.2 # Main effect of time trend (gamma_t)

    # --- Calculate Conditional Treatment Effect (CATE) ---
    # Depends on X3 (first numerical, time-varying) and X8 (categorical, time-varying)
    sqrt_abs_X3 = np.sqrt(np.abs(data['X3']))
    cate_conditions = [
        (data['X8'] == 1) | (data['X8'] == 3),
        (data['X8'] == 2),
        (data['X8'] == 4)
    ]
    cate_choices = [
        treatment_effect_beta + 1.5 * sqrt_abs_X3,
        treatment_effect_beta,
        treatment_effect_beta - 0.5 * sqrt_abs_X3
    ]
    potential_cate = np.select(cate_conditions, cate_choices, default=treatment_effect_beta)



    actual_cate_contribution = potential_cate * data['treated_group'] * data['post_treatment']
    data['CATE'] = potential_cate # Store potential effect magnitude

    # --- Calculate Outcome Y based on Linearity Degree ---
    covariate_names = [f'X{i+1}' for i in range(8)]

    # Define non-linear functions for flexibility
    def nl_func1(x): return x**2
    def nl_func2(x): return np.exp(x / 2) # Scaled exp
    def nl_func3(x): return np.abs(x)
    def nl_func4(x): return np.sqrt(np.abs(x))

    cov_effect = 0

    if linearity_degree == 1: # Fully linear
        for i in range(8):
            cov_effect += beta_x[i] * data[covariate_names[i]]
        time_term = beta_time * data['time_trend']

    elif linearity_degree == 2: # X1, X2, X3, X4 non-linear
        # Apply specific non-linear functions to first 4 covariates
        cov_effect += beta_x[0] * nl_func1(data['X1']) # X1^2 (still 0 or 1)
        cov_effect += beta_x[1] * nl_func2(data['X2']) # exp(X2/2) (more distinct for 0/1)
        cov_effect += beta_x[2] * nl_func3(data['X3']) # abs(X3)
        cov_effect += beta_x[3] * nl_func4(data['X4']) # sqrt(abs(X4))
        # Linear term for remaining covariates
        for i in range(4, 8):
            cov_effect += beta_x[i] * data[covariate_names[i]]
        time_term = beta_time * data['time_trend']

    elif linearity_degree == 3: 
        # Apply different non-linear functions across all covariates
        nl_funcs = [nl_func1, nl_func2, nl_func3, nl_func4, nl_func1, nl_func2, nl_func3, nl_func4] # Example pattern
        for i in range(8):
            cov_effect += beta_x[i] * nl_funcs[i](data[covariate_names[i]])
        # Non-linear time trend
        time_term = beta_time * (data['time_trend']**2)

    # Combine all components for Y
    data['Y'] = (beta_0 + beta_treated * data['treated_group'] +
                 time_term + cov_effect +
                 actual_cate_contribution)

    # --- Add pre-trend bias ---
    if pre_trend_bias_delta != 0:
        pre_trend_effect = pre_trend_bias_delta * data['treated_group'] * (data['time'] - treatment_period) * (1 - data['post_treatment'])
        data['Y'] += pre_trend_effect

    # --- Add final error term ---
    data['Y'] += data['epsilon']

    # --- Final Touches ---
    # Reorder columns for clarity
    cols_order = ['unit_id', 'time', 'treated_group', 'post_treatment', 'propensity_score'] + \
                 covariate_names + ['CATE', 'Y']
    data = data[cols_order]

    return data

# %% [markdown]
# # Experiments

# %%
num_x_covariates = 6
linearity_degree=1

# Set the number of iterations and initialize the counter.
num_iterations = 100
count_at_least_two_non_significant = 0

num_pre_periods=4

num_post_periods=4

epsilon_scale=1

RMSE_per_period=np.zeros([num_iterations,num_post_periods])
MAE_per_period=np.zeros([num_iterations,num_post_periods])
MAPE_per_period=np.zeros([num_iterations,num_post_periods])

list_accumulated_p_values=[]

RMSE_overall=np.zeros([num_iterations])
MAE_overall=np.zeros([num_iterations])
MAPE_overall=np.zeros([num_iterations])

for i in tqdm(range(num_iterations), desc="Progress", unit="iteration"):
    # Generate a random seed for each iteration.
    seed_val = i

    # Generate data with specified hyperparameters.
    data_linear = generate_did_data(
        n_units=200,
        linearity_degree=linearity_degree,
        num_pre_periods=num_pre_periods,
        num_post_periods=num_post_periods,
        pre_trend_bias_delta=0,
        epsilon_scale=epsilon_scale,
        seed=seed_val
    )

    # Define the complex regression formula.
    formula_complex = "Y ~ treated_group + C(time) + C(time):treated_group + X1 + X2+X3+X4+ X5 + X6+X7+X8"
    
    # Fit the model.
    model_complex = smf.ols(formula=formula_complex, data=data_linear).fit()

    CATE_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE'].index
    Pre_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==0)]['CATE'].index
    true_CATE=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE']
    estimated_CATE=np.array(model_complex.params[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])
    final_CATE=np.zeros([int(len(Pre_indexes)/4),num_post_periods])

    for k in range(int(len(Pre_indexes)/4)):
        final_CATE[k,:]=estimated_CATE

    true_CATE=np.array(true_CATE).reshape(final_CATE.shape)
    accumulated_p_values=np.zeros([num_post_periods,int(len(Pre_indexes)/4)])

    for k in range(int(len(Pre_indexes)/4)):
        accumulated_p_values[:,k]=np.array(model_complex.pvalues[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])

    accumulated_p_values=accumulated_p_values.reshape(accumulated_p_values.shape[0]*accumulated_p_values.shape[1])
    list_accumulated_p_values.append(accumulated_p_values)


    RMSE_overall[i]=np.sqrt(np.mean((final_CATE-true_CATE)**2))
    MAE_overall[i]=np.mean(np.abs(final_CATE-true_CATE))
    MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))

    for h in range(num_post_periods):
        RMSE_per_period[i,h]=np.sqrt(np.mean((final_CATE[:,h]-true_CATE[:,h])**2))
        MAE_per_period[i,h]=np.mean(np.abs(final_CATE[:,h]-true_CATE[:,h]))
        MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))


mean_RMSE_overall=np.mean(RMSE_overall)
mean_MAE_overall=np.mean(MAE_overall)
mean_MAPE_overall=np.mean(MAPE_overall)
std_RMSE_overall=np.std(RMSE_overall)
std_MAE_overall=np.std(MAE_overall)
std_MAPE_overall=np.std(MAPE_overall)

print(f"Mean RMSE for {num_iterations} simulations: {mean_RMSE_overall}")
print(f"Standard Deviation RMSE for {num_iterations} simulations: {std_RMSE_overall}")
print(f"Mean MAE for {num_iterations} simulations: {mean_MAE_overall}")
print(f"Standard Deviation MAE for {num_iterations} simulations: {std_MAE_overall}")
print(f"Mean MAPE for {num_iterations} simulations: {mean_MAPE_overall}")
print(f"Standard Deviation MAPE for {num_iterations} simulations: {std_MAPE_overall}")

for h in range(num_post_periods):
    print(f"Mean RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(RMSE_per_period[:,h])}")
    print(f"Standard Deviation RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(RMSE_per_period[:,h])}")
    print(f"Mean MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAE_per_period[:,h])}")
    print(f"Standard Deviation MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAE_per_period[:,h])}")
    print(f"Mean MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAPE_per_period[:,h])}")
    print(f"Standard Deviation MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAPE_per_period[:,h])}")

# === Sheet 1: Metrics Data ===

# 1. Prepare data dictionary for metrics (overall and per_period)
metrics_data_dict = {
    'RMSE_overall': RMSE_overall,
    'MAE_overall': MAE_overall,
    'MAPE_overall': MAPE_overall,
}

# 2. Flatten the _per_period arrays into columns
for i in range(num_post_periods):
    metrics_data_dict[f'RMSE_period_{i}'] = RMSE_per_period[:, i]
    metrics_data_dict[f'MAE_period_{i}'] = MAE_per_period[:, i]
    metrics_data_dict[f'MAPE_period_{i}'] = MAPE_per_period[:, i]

# 3. Create the first DataFrame for metrics
df_metrics = pd.DataFrame(metrics_data_dict)

# === Sheet 2: P-Values Data (Handling Variable Lengths) ===

df_p_values = None # Initialize in case the list is empty

if not list_accumulated_p_values:
    print("Warning: 'list_accumulated_p_values' is empty. P-Value sheet will not be created.")
else:
    # 1. Find the maximum length of the p-value vectors
    max_len = 0
    for vec in list_accumulated_p_values:
        # Check if the element is actually a numpy array or list-like
        if hasattr(vec, '__len__'):
             max_len = max(max_len, len(vec))
        # else: handle potential non-iterable elements if necessary

    if max_len == 0 and list_accumulated_p_values:
         print("Warning: list_accumulated_p_values contains elements but none have length > 0.")
         # Decide how to handle this - maybe create an empty df?

    # 2. Create padded data
    padded_p_values = []
    for i, vec in enumerate(list_accumulated_p_values):
         # Ensure vec is treated as an iterable, default to empty if not applicable
        current_vec = []
        if hasattr(vec, '__len__'):
            current_vec = list(vec) # Convert numpy array to list for easy padding

        # Create a padded row with NaN for missing values
        padded_row = current_vec + [np.nan] * (max_len - len(current_vec))
        padded_p_values.append(padded_row)

    # 3. Create column names for the p-values sheet
    p_value_columns = [f'p_value_{i}' for i in range(max_len)]

    # 4. Create the second DataFrame for p-values
    df_p_values = pd.DataFrame(padded_p_values, columns=p_value_columns)

# === Save to Excel File with Multiple Sheets ===

output_filename_excel = 'OLS_CATE_PS_and_PValues_linearity=1.xlsx'

# Use ExcelWriter to write multiple DataFrames to different sheets
try:
    with pd.ExcelWriter(output_filename_excel, engine='openpyxl') as writer:
        # Write the metrics DataFrame to the first sheet
        df_metrics.to_excel(writer, sheet_name='Metrics', index=False, float_format='%.6f')
        print(f"Metrics data saved to sheet 'Metrics' in {output_filename_excel}")

        # Write the p-values DataFrame to the second sheet (if it exists)
        if df_p_values is not None:
            df_p_values.to_excel(writer, sheet_name='P_Values', index=False, float_format='%.6f')
            print(f"P-Values data saved to sheet 'P_Values' in {output_filename_excel}")
        else:
             # Optionally create an empty sheet or just skip
             print("P-Values sheet was not created as the source list was empty or contained no vectors.")


except ImportError:
    print("\nError: Cannot write Excel file. Please install the 'openpyxl' library.")
    print("You can install it using: pip install openpyxl")
except Exception as e:
    print(f"\nAn error occurred while writing the Excel file: {e}")
# Out:
# Progress:   0%|          | 0/100 [00:00<?, ?iteration/s]
# /tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   1%|          | 1/100 [00:00<00:13,  7.22iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   2%|▏         | 2/100 [00:00<00:13,  7.07iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   3%|▎         | 3/100 [00:00<00:15,  6.18iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   4%|▍         | 4/100 [00:00<00:14,  6.82iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   5%|▌         | 5/100 [00:00<00:12,  7.34iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   6%|▌         | 6/100 [00:00<00:12,  7.59iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   7%|▋         | 7/100 [00:00<00:13,  6.99iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   8%|▊         | 8/100 [00:01<00:13,  6.71iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   9%|▉         | 9/100 [00:01<00:13,  6.81iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  10%|█         | 10/100 [00:01<00:12,  7.00iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  11%|█         | 11/100 [00:01<00:12,  7.13iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  12%|█▏        | 12/100 [00:01<00:12,  7.19iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  13%|█▎        | 13/100 [00:01<00:13,  6.62iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  14%|█▍        | 14/100 [00:02<00:12,  7.01iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  15%|█▌        | 15/100 [00:02<00:11,  7.13iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  16%|█▌        | 16/100 [00:02<00:12,  6.87iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  17%|█▋        | 17/100 [00:02<00:13,  5.97iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  18%|█▊        | 18/100 [00:02<00:14,  5.82iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  19%|█▉        | 19/100 [00:02<00:12,  6.44iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  20%|██        | 20/100 [00:02<00:12,  6.46iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  21%|██        | 21/100 [00:03<00:11,  6.65iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  22%|██▏       | 22/100 [00:03<00:11,  6.92iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  23%|██▎       | 23/100 [00:03<00:10,  7.30iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  24%|██▍       | 24/100 [00:03<00:10,  7.25iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  25%|██▌       | 25/100 [00:03<00:10,  6.97iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  26%|██▌       | 26/100 [00:03<00:11,  6.63iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  27%|██▋       | 27/100 [00:03<00:10,  7.06iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  28%|██▊       | 28/100 [00:04<00:10,  7.19iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  29%|██▉       | 29/100 [00:04<00:09,  7.40iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  30%|███       | 30/100 [00:04<00:09,  7.11iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  31%|███       | 31/100 [00:04<00:10,  6.87iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  32%|███▏      | 32/100 [00:04<00:09,  7.21iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  33%|███▎      | 33/100 [00:04<00:10,  6.52iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  34%|███▍      | 34/100 [00:04<00:09,  6.77iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  35%|███▌      | 35/100 [00:05<00:09,  6.88iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  36%|███▌      | 36/100 [00:05<00:09,  6.57iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  37%|███▋      | 37/100 [00:05<00:09,  6.57iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  38%|███▊      | 38/100 [00:05<00:09,  6.72iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  39%|███▉      | 39/100 [00:05<00:08,  6.88iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  40%|████      | 40/100 [00:05<00:08,  7.16iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  41%|████      | 41/100 [00:05<00:08,  6.76iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  42%|████▏     | 42/100 [00:06<00:08,  7.11iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  43%|████▎     | 43/100 [00:06<00:08,  6.63iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  44%|████▍     | 44/100 [00:06<00:07,  7.14iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  45%|████▌     | 45/100 [00:06<00:07,  7.14iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  46%|████▌     | 46/100 [00:06<00:07,  6.80iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  47%|████▋     | 47/100 [00:06<00:09,  5.77iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  48%|████▊     | 48/100 [00:07<00:08,  6.16iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  49%|████▉     | 49/100 [00:07<00:08,  6.35iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  50%|█████     | 50/100 [00:07<00:07,  6.81iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  51%|█████     | 51/100 [00:07<00:07,  6.55iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  52%|█████▏    | 52/100 [00:07<00:06,  6.87iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  53%|█████▎    | 53/100 [00:07<00:06,  6.86iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  54%|█████▍    | 54/100 [00:07<00:06,  6.58iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  55%|█████▌    | 55/100 [00:08<00:07,  6.26iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  56%|█████▌    | 56/100 [00:08<00:06,  6.62iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  57%|█████▋    | 57/100 [00:08<00:06,  6.60iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  58%|█████▊    | 58/100 [00:08<00:06,  6.43iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  59%|█████▉    | 59/100 [00:08<00:06,  6.51iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  60%|██████    | 60/100 [00:08<00:06,  6.40iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  61%|██████    | 61/100 [00:09<00:05,  6.52iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  62%|██████▏   | 62/100 [00:09<00:06,  6.23iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  63%|██████▎   | 63/100 [00:09<00:05,  6.45iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  64%|██████▍   | 64/100 [00:09<00:05,  6.22iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  65%|██████▌   | 65/100 [00:09<00:05,  6.21iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  66%|██████▌   | 66/100 [00:09<00:05,  6.31iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  67%|██████▋   | 67/100 [00:10<00:05,  6.10iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  68%|██████▊   | 68/100 [00:10<00:04,  6.75iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  69%|██████▉   | 69/100 [00:10<00:04,  6.74iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  70%|███████   | 70/100 [00:10<00:04,  6.13iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  71%|███████   | 71/100 [00:10<00:04,  6.35iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  72%|███████▏  | 72/100 [00:10<00:04,  6.89iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  73%|███████▎  | 73/100 [00:10<00:03,  7.32iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  74%|███████▍  | 74/100 [00:11<00:03,  7.29iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  75%|███████▌  | 75/100 [00:11<00:03,  7.18iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  76%|███████▌  | 76/100 [00:11<00:03,  6.50iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  77%|███████▋  | 77/100 [00:11<00:03,  6.20iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  78%|███████▊  | 78/100 [00:11<00:03,  6.24iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  79%|███████▉  | 79/100 [00:11<00:03,  5.73iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  80%|████████  | 80/100 [00:12<00:03,  6.01iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  81%|████████  | 81/100 [00:12<00:02,  6.45iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  82%|████████▏ | 82/100 [00:12<00:02,  6.40iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  83%|████████▎ | 83/100 [00:12<00:02,  6.37iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  84%|████████▍ | 84/100 [00:12<00:02,  6.49iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  85%|████████▌ | 85/100 [00:12<00:02,  6.54iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  86%|████████▌ | 86/100 [00:12<00:02,  6.22iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  87%|████████▋ | 87/100 [00:13<00:02,  5.84iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  88%|████████▊ | 88/100 [00:13<00:02,  5.63iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  89%|████████▉ | 89/100 [00:13<00:01,  5.83iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  90%|█████████ | 90/100 [00:13<00:01,  5.80iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  91%|█████████ | 91/100 [00:13<00:01,  5.90iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  92%|█████████▏| 92/100 [00:13<00:01,  5.97iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  93%|█████████▎| 93/100 [00:14<00:01,  6.45iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  94%|█████████▍| 94/100 [00:14<00:00,  6.94iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  95%|█████████▌| 95/100 [00:14<00:00,  6.69iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  96%|█████████▌| 96/100 [00:14<00:00,  6.65iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  97%|█████████▋| 97/100 [00:14<00:00,  7.07iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  98%|█████████▊| 98/100 [00:14<00:00,  7.13iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  99%|█████████▉| 99/100 [00:14<00:00,  6.65iteration/s]/tmp/ipykernel_15635/1411125066.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/1411125066.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress: 100%|██████████| 100/100 [00:15<00:00,  6.61iteration/s]
# /home/hugo.souto/.local/lib/python3.10/site-packages/numpy/_core/_methods.py:185: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# Mean RMSE for 100 simulations: 0.8983647183003943
# Standard Deviation RMSE for 100 simulations: 0.032354195944998665
# Mean MAE for 100 simulations: 0.7938258838359326
# Standard Deviation MAE for 100 simulations: 0.026502446790157074
# Mean MAPE for 100 simulations: inf
# Standard Deviation MAPE for 100 simulations: nan
# Mean RMSE for 100 simulations for post-treatment period 1: 0.8988381081140759
# Standard Deviation RMSE for 100 simulations for post-treatment period 1: 0.048861067727973675
# Mean MAE for 100 simulations for post-treatment period 1: 0.7976668674207193
# Standard Deviation MAE for 100 simulations for post-treatment period 1: 0.04503314932040798
# Mean MAPE for 100 simulations for post-treatment period 1: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 1: nan
# Mean RMSE for 100 simulations for post-treatment period 2: 0.8935123314195486
# Standard Deviation RMSE for 100 simulations for post-treatment period 2: 0.04977682185919898
# Mean MAE for 100 simulations for post-treatment period 2: 0.7909961074879877
# Standard Deviation MAE for 100 simulations for post-treatment period 2: 0.04704423428151892
# Mean MAPE for 100 simulations for post-treatment period 2: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 2: nan
# Mean RMSE for 100 simulations for post-treatment period 3: 0.8986735663033579
# Standard Deviation RMSE for 100 simulations for post-treatment period 3: 0.04679700314671465
# Mean MAE for 100 simulations for post-treatment period 3: 0.7961921132176648
# Standard Deviation MAE for 100 simulations for post-treatment period 3: 0.04506514625023041
# Mean MAPE for 100 simulations for post-treatment period 3: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 3: nan
# Mean RMSE for 100 simulations for post-treatment period 4: 0.8992196655240648
# Standard Deviation RMSE for 100 simulations for post-treatment period 4: 0.05370597971219619
# Mean MAE for 100 simulations for post-treatment period 4: 0.7904484472173579
# Standard Deviation MAE for 100 simulations for post-treatment period 4: 0.04994796774890265
# Mean MAPE for 100 simulations for post-treatment period 4: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 4: nan
# Metrics data saved to sheet 'Metrics' in OLS_CATE_PS_and_PValues_linearity=1.xlsx
# P-Values data saved to sheet 'P_Values' in OLS_CATE_PS_and_PValues_linearity=1.xlsx

# %%
num_x_covariates = 6
linearity_degree=2

# Set the number of iterations and initialize the counter.
num_iterations = 100
count_at_least_two_non_significant = 0

num_pre_periods=4

num_post_periods=4

epsilon_scale=1

RMSE_per_period=np.zeros([num_iterations,num_post_periods])
MAE_per_period=np.zeros([num_iterations,num_post_periods])
MAPE_per_period=np.zeros([num_iterations,num_post_periods])

list_accumulated_p_values=[]

RMSE_overall=np.zeros([num_iterations])
MAE_overall=np.zeros([num_iterations])
MAPE_overall=np.zeros([num_iterations])

for i in tqdm(range(num_iterations), desc="Progress", unit="iteration"):
    # Generate a random seed for each iteration.
    seed_val = i

    # Generate data with specified hyperparameters.
    data_linear = generate_did_data(
        n_units=200,
        linearity_degree=linearity_degree,
        num_pre_periods=num_pre_periods,
        num_post_periods=num_post_periods,
        pre_trend_bias_delta=0,
        epsilon_scale=epsilon_scale,
        seed=seed_val
    )

    # Define the complex regression formula.
    formula_complex = "Y ~ treated_group + C(time) + C(time):treated_group + X1 + X2+X3+X4+ X5 + X6+X7+X8"
    
    # Fit the model.
    model_complex = smf.ols(formula=formula_complex, data=data_linear).fit()

    CATE_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE'].index
    Pre_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==0)]['CATE'].index
    true_CATE=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE']
    estimated_CATE=np.array(model_complex.params[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])
    final_CATE=np.zeros([int(len(Pre_indexes)/4),num_post_periods])

    for k in range(int(len(Pre_indexes)/4)):
        final_CATE[k,:]=estimated_CATE

    true_CATE=np.array(true_CATE).reshape(final_CATE.shape)
    accumulated_p_values=np.zeros([num_post_periods,int(len(Pre_indexes)/4)])

    for k in range(int(len(Pre_indexes)/4)):
        accumulated_p_values[:,k]=np.array(model_complex.pvalues[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])

    accumulated_p_values=accumulated_p_values.reshape(accumulated_p_values.shape[0]*accumulated_p_values.shape[1])
    list_accumulated_p_values.append(accumulated_p_values)


    RMSE_overall[i]=np.sqrt(np.mean((final_CATE-true_CATE)**2))
    MAE_overall[i]=np.mean(np.abs(final_CATE-true_CATE))
    MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))

    for h in range(num_post_periods):
        RMSE_per_period[i,h]=np.sqrt(np.mean((final_CATE[:,h]-true_CATE[:,h])**2))
        MAE_per_period[i,h]=np.mean(np.abs(final_CATE[:,h]-true_CATE[:,h]))
        MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))


mean_RMSE_overall=np.mean(RMSE_overall)
mean_MAE_overall=np.mean(MAE_overall)
mean_MAPE_overall=np.mean(MAPE_overall)
std_RMSE_overall=np.std(RMSE_overall)
std_MAE_overall=np.std(MAE_overall)
std_MAPE_overall=np.std(MAPE_overall)

print(f"Mean RMSE for {num_iterations} simulations: {mean_RMSE_overall}")
print(f"Standard Deviation RMSE for {num_iterations} simulations: {std_RMSE_overall}")
print(f"Mean MAE for {num_iterations} simulations: {mean_MAE_overall}")
print(f"Standard Deviation MAE for {num_iterations} simulations: {std_MAE_overall}")
print(f"Mean MAPE for {num_iterations} simulations: {mean_MAPE_overall}")
print(f"Standard Deviation MAPE for {num_iterations} simulations: {std_MAPE_overall}")

for h in range(num_post_periods):
    print(f"Mean RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(RMSE_per_period[:,h])}")
    print(f"Standard Deviation RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(RMSE_per_period[:,h])}")
    print(f"Mean MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAE_per_period[:,h])}")
    print(f"Standard Deviation MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAE_per_period[:,h])}")
    print(f"Mean MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAPE_per_period[:,h])}")
    print(f"Standard Deviation MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAPE_per_period[:,h])}")

# === Sheet 1: Metrics Data ===

# 1. Prepare data dictionary for metrics (overall and per_period)
metrics_data_dict = {
    'RMSE_overall': RMSE_overall,
    'MAE_overall': MAE_overall,
    'MAPE_overall': MAPE_overall,
}

# 2. Flatten the _per_period arrays into columns
for i in range(num_post_periods):
    metrics_data_dict[f'RMSE_period_{i}'] = RMSE_per_period[:, i]
    metrics_data_dict[f'MAE_period_{i}'] = MAE_per_period[:, i]
    metrics_data_dict[f'MAPE_period_{i}'] = MAPE_per_period[:, i]

# 3. Create the first DataFrame for metrics
df_metrics = pd.DataFrame(metrics_data_dict)

# === Sheet 2: P-Values Data (Handling Variable Lengths) ===

df_p_values = None # Initialize in case the list is empty

if not list_accumulated_p_values:
    print("Warning: 'list_accumulated_p_values' is empty. P-Value sheet will not be created.")
else:
    # 1. Find the maximum length of the p-value vectors
    max_len = 0
    for vec in list_accumulated_p_values:
        # Check if the element is actually a numpy array or list-like
        if hasattr(vec, '__len__'):
             max_len = max(max_len, len(vec))
        # else: handle potential non-iterable elements if necessary

    if max_len == 0 and list_accumulated_p_values:
         print("Warning: list_accumulated_p_values contains elements but none have length > 0.")
         # Decide how to handle this - maybe create an empty df?

    # 2. Create padded data
    padded_p_values = []
    for i, vec in enumerate(list_accumulated_p_values):
         # Ensure vec is treated as an iterable, default to empty if not applicable
        current_vec = []
        if hasattr(vec, '__len__'):
            current_vec = list(vec) # Convert numpy array to list for easy padding

        # Create a padded row with NaN for missing values
        padded_row = current_vec + [np.nan] * (max_len - len(current_vec))
        padded_p_values.append(padded_row)

    # 3. Create column names for the p-values sheet
    p_value_columns = [f'p_value_{i}' for i in range(max_len)]

    # 4. Create the second DataFrame for p-values
    df_p_values = pd.DataFrame(padded_p_values, columns=p_value_columns)

# === Save to Excel File with Multiple Sheets ===

output_filename_excel = 'OLS_CATE_PS_and_PValues_linearity=2.xlsx'

# Use ExcelWriter to write multiple DataFrames to different sheets
try:
    with pd.ExcelWriter(output_filename_excel, engine='openpyxl') as writer:
        # Write the metrics DataFrame to the first sheet
        df_metrics.to_excel(writer, sheet_name='Metrics', index=False, float_format='%.6f')
        print(f"Metrics data saved to sheet 'Metrics' in {output_filename_excel}")

        # Write the p-values DataFrame to the second sheet (if it exists)
        if df_p_values is not None:
            df_p_values.to_excel(writer, sheet_name='P_Values', index=False, float_format='%.6f')
            print(f"P-Values data saved to sheet 'P_Values' in {output_filename_excel}")
        else:
             # Optionally create an empty sheet or just skip
             print("P-Values sheet was not created as the source list was empty or contained no vectors.")


except ImportError:
    print("\nError: Cannot write Excel file. Please install the 'openpyxl' library.")
    print("You can install it using: pip install openpyxl")
except Exception as e:
    print(f"\nAn error occurred while writing the Excel file: {e}")
# Out:
# Progress:   0%|          | 0/100 [00:00<?, ?iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   1%|          | 1/100 [00:00<00:16,  5.96iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   2%|▏         | 2/100 [00:00<00:13,  7.33iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   3%|▎         | 3/100 [00:00<00:12,  8.03iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   4%|▍         | 4/100 [00:00<00:11,  8.42iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   5%|▌         | 5/100 [00:00<00:12,  7.87iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   6%|▌         | 6/100 [00:00<00:12,  7.42iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   7%|▋         | 7/100 [00:00<00:13,  7.11iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   8%|▊         | 8/100 [00:01<00:13,  6.85iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   9%|▉         | 9/100 [00:01<00:13,  6.96iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  10%|█         | 10/100 [00:01<00:13,  6.82iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  11%|█         | 11/100 [00:01<00:12,  7.23iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  12%|█▏        | 12/100 [00:01<00:11,  7.49iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  13%|█▎        | 13/100 [00:01<00:11,  7.53iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  14%|█▍        | 14/100 [00:01<00:11,  7.64iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  15%|█▌        | 15/100 [00:02<00:12,  7.07iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  16%|█▌        | 16/100 [00:02<00:12,  6.74iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  17%|█▋        | 17/100 [00:02<00:12,  6.58iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  18%|█▊        | 18/100 [00:02<00:11,  6.85iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  19%|█▉        | 19/100 [00:02<00:12,  6.66iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  20%|██        | 20/100 [00:02<00:12,  6.55iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  21%|██        | 21/100 [00:02<00:11,  7.06iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  22%|██▏       | 22/100 [00:03<00:10,  7.37iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  23%|██▎       | 23/100 [00:03<00:10,  7.57iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  24%|██▍       | 24/100 [00:03<00:09,  7.67iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  25%|██▌       | 25/100 [00:03<00:11,  6.74iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  26%|██▌       | 26/100 [00:03<00:10,  7.12iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  27%|██▋       | 27/100 [00:03<00:10,  7.23iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  28%|██▊       | 28/100 [00:03<00:10,  7.11iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  29%|██▉       | 29/100 [00:04<00:10,  6.78iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  30%|███       | 30/100 [00:04<00:10,  6.86iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  31%|███       | 31/100 [00:04<00:09,  7.13iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  32%|███▏      | 32/100 [00:04<00:09,  6.93iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  33%|███▎      | 33/100 [00:04<00:09,  6.80iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  34%|███▍      | 34/100 [00:04<00:09,  6.71iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  35%|███▌      | 35/100 [00:04<00:09,  7.01iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  36%|███▌      | 36/100 [00:05<00:08,  7.23iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  37%|███▋      | 37/100 [00:05<00:08,  7.22iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  38%|███▊      | 38/100 [00:05<00:08,  6.96iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  39%|███▉      | 39/100 [00:05<00:08,  7.29iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  40%|████      | 40/100 [00:05<00:08,  7.32iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  41%|████      | 41/100 [00:05<00:07,  7.60iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  42%|████▏     | 42/100 [00:05<00:08,  7.16iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  43%|████▎     | 43/100 [00:06<00:07,  7.50iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  44%|████▍     | 44/100 [00:06<00:07,  7.04iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  45%|████▌     | 45/100 [00:06<00:07,  7.43iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  46%|████▌     | 46/100 [00:06<00:07,  7.00iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  47%|████▋     | 47/100 [00:06<00:07,  6.91iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  48%|████▊     | 48/100 [00:06<00:07,  6.98iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  49%|████▉     | 49/100 [00:06<00:07,  7.16iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  50%|█████     | 50/100 [00:07<00:07,  6.86iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  51%|█████     | 51/100 [00:07<00:06,  7.24iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  52%|█████▏    | 52/100 [00:07<00:06,  6.92iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  53%|█████▎    | 53/100 [00:07<00:06,  7.38iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  54%|█████▍    | 54/100 [00:07<00:06,  7.38iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  55%|█████▌    | 55/100 [00:07<00:06,  6.83iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  56%|█████▌    | 56/100 [00:07<00:06,  7.03iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  57%|█████▋    | 57/100 [00:08<00:06,  6.46iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  58%|█████▊    | 58/100 [00:08<00:06,  6.42iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  59%|█████▉    | 59/100 [00:08<00:05,  6.87iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  60%|██████    | 60/100 [00:08<00:06,  6.57iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  61%|██████    | 61/100 [00:08<00:06,  6.49iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  62%|██████▏   | 62/100 [00:08<00:05,  6.51iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  63%|██████▎   | 63/100 [00:08<00:05,  6.56iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  64%|██████▍   | 64/100 [00:09<00:05,  6.58iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  65%|██████▌   | 65/100 [00:09<00:06,  5.79iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  66%|██████▌   | 66/100 [00:09<00:06,  5.64iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  67%|██████▋   | 67/100 [00:09<00:05,  5.91iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  68%|██████▊   | 68/100 [00:09<00:05,  5.91iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  69%|██████▉   | 69/100 [00:09<00:04,  6.54iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  70%|███████   | 70/100 [00:10<00:04,  6.73iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  71%|███████   | 71/100 [00:10<00:04,  7.15iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  72%|███████▏  | 72/100 [00:10<00:03,  7.10iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  73%|███████▎  | 73/100 [00:10<00:03,  6.86iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  74%|███████▍  | 74/100 [00:10<00:03,  6.77iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  75%|███████▌  | 75/100 [00:10<00:03,  7.08iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  76%|███████▌  | 76/100 [00:10<00:03,  7.46iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  77%|███████▋  | 77/100 [00:11<00:03,  7.12iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  78%|███████▊  | 78/100 [00:11<00:03,  6.98iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  79%|███████▉  | 79/100 [00:11<00:03,  6.80iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  80%|████████  | 80/100 [00:11<00:03,  6.66iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  81%|████████  | 81/100 [00:11<00:02,  7.22iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  82%|████████▏ | 82/100 [00:11<00:02,  6.90iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  83%|████████▎ | 83/100 [00:11<00:02,  7.07iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  84%|████████▍ | 84/100 [00:12<00:02,  6.97iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  85%|████████▌ | 85/100 [00:12<00:02,  7.33iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  86%|████████▌ | 86/100 [00:12<00:01,  7.57iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  87%|████████▋ | 87/100 [00:12<00:01,  7.41iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  88%|████████▊ | 88/100 [00:12<00:01,  7.28iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  89%|████████▉ | 89/100 [00:12<00:01,  7.09iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  90%|█████████ | 90/100 [00:12<00:01,  7.45iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  91%|█████████ | 91/100 [00:13<00:01,  7.52iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  92%|█████████▏| 92/100 [00:13<00:01,  7.58iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  93%|█████████▎| 93/100 [00:13<00:00,  7.79iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  94%|█████████▍| 94/100 [00:13<00:00,  7.82iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  95%|█████████▌| 95/100 [00:13<00:00,  7.35iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  96%|█████████▌| 96/100 [00:13<00:00,  6.91iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  97%|█████████▋| 97/100 [00:13<00:00,  6.44iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  98%|█████████▊| 98/100 [00:14<00:00,  6.22iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  99%|█████████▉| 99/100 [00:14<00:00,  6.26iteration/s]/tmp/ipykernel_15635/2928568421.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2928568421.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress: 100%|██████████| 100/100 [00:14<00:00,  6.97iteration/s]
# /home/hugo.souto/.local/lib/python3.10/site-packages/numpy/_core/_methods.py:185: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# Mean RMSE for 100 simulations: 0.9054549390429928
# Standard Deviation RMSE for 100 simulations: 0.037642034117250305
# Mean MAE for 100 simulations: 0.7961892599525594
# Standard Deviation MAE for 100 simulations: 0.029187512899409192
# Mean MAPE for 100 simulations: inf
# Standard Deviation MAPE for 100 simulations: nan
# Mean RMSE for 100 simulations for post-treatment period 1: 0.9050465051864512
# Standard Deviation RMSE for 100 simulations for post-treatment period 1: 0.05470091423519173
# Mean MAE for 100 simulations for post-treatment period 1: 0.7997262658936043
# Standard Deviation MAE for 100 simulations for post-treatment period 1: 0.04623783523771208
# Mean MAPE for 100 simulations for post-treatment period 1: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 1: nan
# Mean RMSE for 100 simulations for post-treatment period 2: 0.9001437727908119
# Standard Deviation RMSE for 100 simulations for post-treatment period 2: 0.04888738061630037
# Mean MAE for 100 simulations for post-treatment period 2: 0.7921567161360766
# Standard Deviation MAE for 100 simulations for post-treatment period 2: 0.04618899873879187
# Mean MAPE for 100 simulations for post-treatment period 2: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 2: nan
# Mean RMSE for 100 simulations for post-treatment period 3: 0.9081420839476293
# Standard Deviation RMSE for 100 simulations for post-treatment period 3: 0.056049230296204344
# Mean MAE for 100 simulations for post-treatment period 3: 0.8004446210222911
# Standard Deviation MAE for 100 simulations for post-treatment period 3: 0.04822748677791444
# Mean MAPE for 100 simulations for post-treatment period 3: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 3: nan
# Mean RMSE for 100 simulations for post-treatment period 4: 0.9050198904116781
# Standard Deviation RMSE for 100 simulations for post-treatment period 4: 0.0582027519886819
# Mean MAE for 100 simulations for post-treatment period 4: 0.7924294367582653
# Standard Deviation MAE for 100 simulations for post-treatment period 4: 0.04976338255977809
# Mean MAPE for 100 simulations for post-treatment period 4: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 4: nan
# Metrics data saved to sheet 'Metrics' in OLS_CATE_PS_and_PValues_linearity=2.xlsx
# P-Values data saved to sheet 'P_Values' in OLS_CATE_PS_and_PValues_linearity=2.xlsx

# %%
num_x_covariates = 6
linearity_degree=3

# Set the number of iterations and initialize the counter.
num_iterations = 100
count_at_least_two_non_significant = 0

num_pre_periods=4

num_post_periods=4

epsilon_scale=1

RMSE_per_period=np.zeros([num_iterations,num_post_periods])
MAE_per_period=np.zeros([num_iterations,num_post_periods])
MAPE_per_period=np.zeros([num_iterations,num_post_periods])

list_accumulated_p_values=[]

RMSE_overall=np.zeros([num_iterations])
MAE_overall=np.zeros([num_iterations])
MAPE_overall=np.zeros([num_iterations])

for i in tqdm(range(num_iterations), desc="Progress", unit="iteration"):
    # Generate a random seed for each iteration.
    seed_val = i

    # Generate data with specified hyperparameters.
    data_linear = generate_did_data(
        n_units=200,
        linearity_degree=linearity_degree,
        num_pre_periods=num_pre_periods,
        num_post_periods=num_post_periods,
        pre_trend_bias_delta=0,
        epsilon_scale=epsilon_scale,
        seed=seed_val
    )

    # Define the complex regression formula.
    formula_complex = "Y ~ treated_group + C(time) + C(time):treated_group + X1 + X2+X3+X4+ X5 + X6+X7+X8"
    
    # Fit the model.
    model_complex = smf.ols(formula=formula_complex, data=data_linear).fit()

    CATE_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE'].index
    Pre_indexes=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==0)]['CATE'].index
    true_CATE=data_linear[(data_linear['treated_group']==1) & (data_linear['post_treatment']==1)]['CATE']
    estimated_CATE=np.array(model_complex.params[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])
    final_CATE=np.zeros([int(len(Pre_indexes)/4),num_post_periods])

    for k in range(int(len(Pre_indexes)/4)):
        final_CATE[k,:]=estimated_CATE

    true_CATE=np.array(true_CATE).reshape(final_CATE.shape)
    accumulated_p_values=np.zeros([num_post_periods,int(len(Pre_indexes)/4)])

    for k in range(int(len(Pre_indexes)/4)):
        accumulated_p_values[:,k]=np.array(model_complex.pvalues[[f'C(time)[T.{t}]:treated_group' for t in range(num_pre_periods, num_pre_periods + num_post_periods)]])

    accumulated_p_values=accumulated_p_values.reshape(accumulated_p_values.shape[0]*accumulated_p_values.shape[1])
    list_accumulated_p_values.append(accumulated_p_values)


    RMSE_overall[i]=np.sqrt(np.mean((final_CATE-true_CATE)**2))
    MAE_overall[i]=np.mean(np.abs(final_CATE-true_CATE))
    MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))

    for h in range(num_post_periods):
        RMSE_per_period[i,h]=np.sqrt(np.mean((final_CATE[:,h]-true_CATE[:,h])**2))
        MAE_per_period[i,h]=np.mean(np.abs(final_CATE[:,h]-true_CATE[:,h]))
        MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))


mean_RMSE_overall=np.mean(RMSE_overall)
mean_MAE_overall=np.mean(MAE_overall)
mean_MAPE_overall=np.mean(MAPE_overall)
std_RMSE_overall=np.std(RMSE_overall)
std_MAE_overall=np.std(MAE_overall)
std_MAPE_overall=np.std(MAPE_overall)

print(f"Mean RMSE for {num_iterations} simulations: {mean_RMSE_overall}")
print(f"Standard Deviation RMSE for {num_iterations} simulations: {std_RMSE_overall}")
print(f"Mean MAE for {num_iterations} simulations: {mean_MAE_overall}")
print(f"Standard Deviation MAE for {num_iterations} simulations: {std_MAE_overall}")
print(f"Mean MAPE for {num_iterations} simulations: {mean_MAPE_overall}")
print(f"Standard Deviation MAPE for {num_iterations} simulations: {std_MAPE_overall}")

for h in range(num_post_periods):
    print(f"Mean RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(RMSE_per_period[:,h])}")
    print(f"Standard Deviation RMSE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(RMSE_per_period[:,h])}")
    print(f"Mean MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAE_per_period[:,h])}")
    print(f"Standard Deviation MAE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAE_per_period[:,h])}")
    print(f"Mean MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.mean(MAPE_per_period[:,h])}")
    print(f"Standard Deviation MAPE for {num_iterations} simulations for post-treatment period {h+1}: {np.std(MAPE_per_period[:,h])}")

# === Sheet 1: Metrics Data ===

# 1. Prepare data dictionary for metrics (overall and per_period)
metrics_data_dict = {
    'RMSE_overall': RMSE_overall,
    'MAE_overall': MAE_overall,
    'MAPE_overall': MAPE_overall,
}

# 2. Flatten the _per_period arrays into columns
for i in range(num_post_periods):
    metrics_data_dict[f'RMSE_period_{i}'] = RMSE_per_period[:, i]
    metrics_data_dict[f'MAE_period_{i}'] = MAE_per_period[:, i]
    metrics_data_dict[f'MAPE_period_{i}'] = MAPE_per_period[:, i]

# 3. Create the first DataFrame for metrics
df_metrics = pd.DataFrame(metrics_data_dict)

# === Sheet 2: P-Values Data (Handling Variable Lengths) ===

df_p_values = None # Initialize in case the list is empty

if not list_accumulated_p_values:
    print("Warning: 'list_accumulated_p_values' is empty. P-Value sheet will not be created.")
else:
    # 1. Find the maximum length of the p-value vectors
    max_len = 0
    for vec in list_accumulated_p_values:
        # Check if the element is actually a numpy array or list-like
        if hasattr(vec, '__len__'):
             max_len = max(max_len, len(vec))
        # else: handle potential non-iterable elements if necessary

    if max_len == 0 and list_accumulated_p_values:
         print("Warning: list_accumulated_p_values contains elements but none have length > 0.")
         # Decide how to handle this - maybe create an empty df?

    # 2. Create padded data
    padded_p_values = []
    for i, vec in enumerate(list_accumulated_p_values):
         # Ensure vec is treated as an iterable, default to empty if not applicable
        current_vec = []
        if hasattr(vec, '__len__'):
            current_vec = list(vec) # Convert numpy array to list for easy padding

        # Create a padded row with NaN for missing values
        padded_row = current_vec + [np.nan] * (max_len - len(current_vec))
        padded_p_values.append(padded_row)

    # 3. Create column names for the p-values sheet
    p_value_columns = [f'p_value_{i}' for i in range(max_len)]

    # 4. Create the second DataFrame for p-values
    df_p_values = pd.DataFrame(padded_p_values, columns=p_value_columns)

# === Save to Excel File with Multiple Sheets ===

output_filename_excel = 'OLS_CATE_PS_and_PValues_linearity=3.xlsx'

# Use ExcelWriter to write multiple DataFrames to different sheets
try:
    with pd.ExcelWriter(output_filename_excel, engine='openpyxl') as writer:
        # Write the metrics DataFrame to the first sheet
        df_metrics.to_excel(writer, sheet_name='Metrics', index=False, float_format='%.6f')
        print(f"Metrics data saved to sheet 'Metrics' in {output_filename_excel}")

        # Write the p-values DataFrame to the second sheet (if it exists)
        if df_p_values is not None:
            df_p_values.to_excel(writer, sheet_name='P_Values', index=False, float_format='%.6f')
            print(f"P-Values data saved to sheet 'P_Values' in {output_filename_excel}")
        else:
             # Optionally create an empty sheet or just skip
             print("P-Values sheet was not created as the source list was empty or contained no vectors.")


except ImportError:
    print("\nError: Cannot write Excel file. Please install the 'openpyxl' library.")
    print("You can install it using: pip install openpyxl")
except Exception as e:
    print(f"\nAn error occurred while writing the Excel file: {e}")
# Out:
# Progress:   0%|          | 0/100 [00:00<?, ?iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   1%|          | 1/100 [00:00<00:17,  5.60iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   2%|▏         | 2/100 [00:00<00:16,  6.04iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   3%|▎         | 3/100 [00:00<00:15,  6.24iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   4%|▍         | 4/100 [00:00<00:13,  7.01iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   5%|▌         | 5/100 [00:00<00:13,  7.09iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   6%|▌         | 6/100 [00:00<00:13,  7.15iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   7%|▋         | 7/100 [00:01<00:13,  7.01iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   8%|▊         | 8/100 [00:01<00:13,  6.80iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:   9%|▉         | 9/100 [00:01<00:13,  6.81iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  10%|█         | 10/100 [00:01<00:13,  6.49iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  11%|█         | 11/100 [00:01<00:13,  6.60iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  12%|█▏        | 12/100 [00:01<00:13,  6.73iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  13%|█▎        | 13/100 [00:01<00:12,  6.88iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  14%|█▍        | 14/100 [00:02<00:12,  6.72iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  15%|█▌        | 15/100 [00:02<00:12,  6.99iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  16%|█▌        | 16/100 [00:02<00:13,  6.45iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  17%|█▋        | 17/100 [00:02<00:12,  6.61iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  18%|█▊        | 18/100 [00:02<00:13,  6.11iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  19%|█▉        | 19/100 [00:02<00:13,  6.00iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  20%|██        | 20/100 [00:03<00:12,  6.49iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  21%|██        | 21/100 [00:03<00:11,  6.68iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  22%|██▏       | 22/100 [00:03<00:11,  6.84iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  23%|██▎       | 23/100 [00:03<00:11,  6.71iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  24%|██▍       | 24/100 [00:03<00:10,  6.92iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  25%|██▌       | 25/100 [00:03<00:10,  7.32iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  26%|██▌       | 26/100 [00:03<00:11,  6.38iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  27%|██▋       | 27/100 [00:04<00:11,  6.41iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  28%|██▊       | 28/100 [00:04<00:11,  6.38iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  29%|██▉       | 29/100 [00:04<00:10,  6.87iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  30%|███       | 30/100 [00:04<00:10,  6.64iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  31%|███       | 31/100 [00:04<00:09,  6.94iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  32%|███▏      | 32/100 [00:04<00:09,  7.08iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  33%|███▎      | 33/100 [00:04<00:09,  6.76iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  34%|███▍      | 34/100 [00:05<00:09,  6.88iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  35%|███▌      | 35/100 [00:05<00:09,  7.01iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  36%|███▌      | 36/100 [00:05<00:09,  6.73iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  37%|███▋      | 37/100 [00:05<00:09,  6.72iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  38%|███▊      | 38/100 [00:05<00:09,  6.30iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  39%|███▉      | 39/100 [00:05<00:09,  6.18iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  40%|████      | 40/100 [00:06<00:09,  6.35iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  41%|████      | 41/100 [00:06<00:08,  6.84iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  42%|████▏     | 42/100 [00:06<00:08,  7.09iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  43%|████▎     | 43/100 [00:06<00:07,  7.34iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  44%|████▍     | 44/100 [00:06<00:07,  7.19iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  45%|████▌     | 45/100 [00:06<00:07,  7.22iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  46%|████▌     | 46/100 [00:06<00:07,  7.02iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  47%|████▋     | 47/100 [00:06<00:07,  7.21iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  48%|████▊     | 48/100 [00:07<00:06,  7.54iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  49%|████▉     | 49/100 [00:07<00:06,  7.56iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  50%|█████     | 50/100 [00:07<00:06,  7.66iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  51%|█████     | 51/100 [00:07<00:06,  7.00iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  52%|█████▏    | 52/100 [00:07<00:07,  6.67iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  53%|█████▎    | 53/100 [00:07<00:07,  6.60iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  54%|█████▍    | 54/100 [00:08<00:07,  6.40iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  55%|█████▌    | 55/100 [00:08<00:06,  6.58iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  56%|█████▌    | 56/100 [00:08<00:06,  6.81iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  57%|█████▋    | 57/100 [00:08<00:06,  7.15iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  58%|█████▊    | 58/100 [00:08<00:06,  6.71iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  59%|█████▉    | 59/100 [00:08<00:05,  7.06iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  60%|██████    | 60/100 [00:08<00:05,  7.16iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  61%|██████    | 61/100 [00:08<00:05,  6.85iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  62%|██████▏   | 62/100 [00:09<00:05,  6.76iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  63%|██████▎   | 63/100 [00:09<00:05,  6.86iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  64%|██████▍   | 64/100 [00:09<00:05,  6.74iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  65%|██████▌   | 65/100 [00:09<00:05,  6.64iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  66%|██████▌   | 66/100 [00:09<00:05,  6.57iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  67%|██████▋   | 67/100 [00:09<00:04,  6.68iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  68%|██████▊   | 68/100 [00:10<00:04,  7.09iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  69%|██████▉   | 69/100 [00:10<00:04,  7.31iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  70%|███████   | 70/100 [00:10<00:03,  7.62iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  71%|███████   | 71/100 [00:10<00:03,  7.80iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  72%|███████▏  | 72/100 [00:10<00:03,  8.00iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  73%|███████▎  | 73/100 [00:10<00:03,  8.08iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  74%|███████▍  | 74/100 [00:10<00:03,  8.05iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  75%|███████▌  | 75/100 [00:10<00:03,  8.09iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  76%|███████▌  | 76/100 [00:10<00:02,  8.11iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  77%|███████▋  | 77/100 [00:11<00:02,  7.91iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  78%|███████▊  | 78/100 [00:11<00:03,  7.02iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  79%|███████▉  | 79/100 [00:11<00:02,  7.25iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  80%|████████  | 80/100 [00:11<00:02,  7.39iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  81%|████████  | 81/100 [00:11<00:02,  7.38iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  82%|████████▏ | 82/100 [00:11<00:02,  6.50iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  83%|████████▎ | 83/100 [00:12<00:02,  6.40iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  84%|████████▍ | 84/100 [00:12<00:02,  6.78iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  85%|████████▌ | 85/100 [00:12<00:02,  7.09iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  86%|████████▌ | 86/100 [00:12<00:01,  7.43iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  87%|████████▋ | 87/100 [00:12<00:01,  7.47iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  88%|████████▊ | 88/100 [00:12<00:01,  7.16iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  89%|████████▉ | 89/100 [00:12<00:01,  7.14iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  90%|█████████ | 90/100 [00:12<00:01,  7.18iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  91%|█████████ | 91/100 [00:13<00:01,  6.71iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  92%|█████████▏| 92/100 [00:13<00:01,  6.69iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  93%|█████████▎| 93/100 [00:13<00:01,  6.86iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  94%|█████████▍| 94/100 [00:13<00:00,  6.90iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  95%|█████████▌| 95/100 [00:13<00:00,  6.81iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  96%|█████████▌| 96/100 [00:13<00:00,  5.78iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  97%|█████████▋| 97/100 [00:14<00:00,  5.72iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  98%|█████████▊| 98/100 [00:14<00:00,  5.93iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress:  99%|█████████▉| 99/100 [00:14<00:00,  6.14iteration/s]/tmp/ipykernel_15635/2053257712.py:66: RuntimeWarning: divide by zero encountered in divide
#   MAPE_overall[i]=np.mean(np.abs((final_CATE-true_CATE)/true_CATE))
# /tmp/ipykernel_15635/2053257712.py:71: RuntimeWarning: divide by zero encountered in divide
#   MAPE_per_period[i,h]=np.mean(np.abs((final_CATE[:,h]-true_CATE[:,h])/true_CATE[:,h]))
# Progress: 100%|██████████| 100/100 [00:14<00:00,  6.85iteration/s]
# /home/hugo.souto/.local/lib/python3.10/site-packages/numpy/_core/_methods.py:185: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# Mean RMSE for 100 simulations: 1.0190804986939919
# Standard Deviation RMSE for 100 simulations: 0.09930136068670775
# Mean MAE for 100 simulations: 0.8582972158593375
# Standard Deviation MAE for 100 simulations: 0.0726645166091533
# Mean MAPE for 100 simulations: inf
# Standard Deviation MAPE for 100 simulations: nan
# Mean RMSE for 100 simulations for post-treatment period 1: 0.9984831008427842
# Standard Deviation RMSE for 100 simulations for post-treatment period 1: 0.14217142810131655
# Mean MAE for 100 simulations for post-treatment period 1: 0.8481632030053007
# Standard Deviation MAE for 100 simulations for post-treatment period 1: 0.11109213313216951
# Mean MAPE for 100 simulations for post-treatment period 1: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 1: nan
# Mean RMSE for 100 simulations for post-treatment period 2: 1.0280313676529724
# Standard Deviation RMSE for 100 simulations for post-treatment period 2: 0.17412860780351053
# Mean MAE for 100 simulations for post-treatment period 2: 0.8712151734118311
# Standard Deviation MAE for 100 simulations for post-treatment period 2: 0.12983177788630326
# Mean MAPE for 100 simulations for post-treatment period 2: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 2: nan
# Mean RMSE for 100 simulations for post-treatment period 3: 0.9773407744253038
# Standard Deviation RMSE for 100 simulations for post-treatment period 3: 0.12475885455102216
# Mean MAE for 100 simulations for post-treatment period 3: 0.8385263099634852
# Standard Deviation MAE for 100 simulations for post-treatment period 3: 0.09522249002631604
# Mean MAPE for 100 simulations for post-treatment period 3: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 3: nan
# Mean RMSE for 100 simulations for post-treatment period 4: 1.03917377227782
# Standard Deviation RMSE for 100 simulations for post-treatment period 4: 0.19634388074558573
# Mean MAE for 100 simulations for post-treatment period 4: 0.8752841770567329
# Standard Deviation MAE for 100 simulations for post-treatment period 4: 0.15567126254463998
# Mean MAPE for 100 simulations for post-treatment period 4: inf
# Standard Deviation MAPE for 100 simulations for post-treatment period 4: nan
# Metrics data saved to sheet 'Metrics' in OLS_CATE_PS_and_PValues_linearity=3.xlsx
# P-Values data saved to sheet 'P_Values' in OLS_CATE_PS_and_PValues_linearity=3.xlsx
